# %%
import sys
sys.path.append("../scripts")

# %%
from Generate_template import generate_asset_data  # or paste the function in the notebook

_, _, _, task_list_df, _ = generate_asset_data()
task_list_df.head(50)
# Out:
#    Equipment ID              Task ID    Task Type  \
# 0         EQ001        INSPECT_MOTOR   Inspection
# 1         EQ001           LUBE_MOTOR  Lubrication
# 2         EQ002         INSPECT_MILL   Inspection
# 3         EQ002            LUBE_MILL  Lubrication
# 4         EQ003        INSPECT_MOTOR   Inspection
# 5         EQ003           LUBE_MOTOR  Lubrication
# 6         EQ004         INSPECT_PUMP   Inspection
# 7         EQ004            LUBE_PUMP  Lubrication
# 8         EQ005  INSPECT_UG_CONVEYOR   Inspection
# 9         EQ005     LUBE_UG_CONVEYOR  Lubrication
# 10        EQ006  INSPECT_UG_CONVEYOR   Inspection
# 11        EQ006     LUBE_UG_CONVEYOR  Lubrication
# 12        EQ007          INSPECT_FAN   Inspection
# 13        EQ007             LUBE_FAN  Lubrication
# 14        EQ008        INSPECT_MOTOR   Inspection
# 15        EQ008           LUBE_MOTOR  Lubrication
# 16        EQ009  INSPECT_UG_CONVEYOR   Inspection
# 17        EQ009     LUBE_UG_CONVEYOR  Lubrication
# 18        EQ010        INSPECT_HOIST   Inspection
# 19        EQ010           LUBE_HOIST  Lubrication
# 20        EQ011         INSPECT_MILL   Inspection
# 21        EQ011            LUBE_MILL  Lubrication
# 22        EQ012         INSPECT_PUMP   Inspection
# 23        EQ012            LUBE_PUMP  Lubrication
# 24        EQ013          INSPECT_FAN   Inspection
# 25        EQ013             LUBE_FAN  Lubrication
# 26        EQ014  INSPECT_UG_CONVEYOR   Inspection
# 27        EQ014     LUBE_UG_CONVEYOR  Lubrication
# 28        EQ015  INSPECT_UG_CONVEYOR   Inspection
# 29        EQ015     LUBE_UG_CONVEYOR  Lubrication
# 30        EQ016        INSPECT_HOIST   Inspection
# 31        EQ016           LUBE_HOIST  Lubrication
# 32        EQ017        INSPECT_MOTOR   Inspection
# 33        EQ017           LUBE_MOTOR  Lubrication
# 34        EQ018         INSPECT_MILL   Inspection
# 35        EQ018            LUBE_MILL  Lubrication
# 36        EQ019        INSPECT_MOTOR   Inspection
# 37        EQ019           LUBE_MOTOR  Lubrication
# 38        EQ020        INSPECT_MOTOR   Inspection
# 39        EQ020           LUBE_MOTOR  Lubrication
# 40        EQ021         INSPECT_PUMP   Inspection
# 41        EQ021            LUBE_PUMP  Lubrication
# 42        EQ022         INSPECT_MILL   Inspection
# 43        EQ022            LUBE_MILL  Lubrication
# 44        EQ023         INSPECT_MILL   Inspection
# 45        EQ023            LUBE_MILL  Lubrication
# 46        EQ024  INSPECT_UG_CONVEYOR   Inspection
# 47        EQ024     LUBE_UG_CONVEYOR  Lubrication
# 48        EQ025         INSPECT_PUMP   Inspection
# 49        EQ025            LUBE_PUMP  Lubrication
#
#                        Description Frequency
# 0           Inspect motor annually  365 days
# 1         Lubricate motor bearings   90 days
# 2            Inspect mill annually  365 days
# 3          Lubricate mill bearings   90 days
# 4           Inspect motor annually  365 days
# 5         Lubricate motor bearings   90 days
# 6            Inspect pump annually  365 days
# 7          Lubricate pump bearings   90 days
# 8     Inspect ug_conveyor annually  365 days
# 9   Lubricate ug_conveyor bearings   90 days
# 10    Inspect ug_conveyor annually  365 days
# 11  Lubricate ug_conveyor bearings   90 days
# 12            Inspect fan annually  365 days
# 13          Lubricate fan bearings   90 days
# 14          Inspect motor annually  365 days
# 15        Lubricate motor bearings   90 days
# 16    Inspect ug_conveyor annually  365 days
# 17  Lubricate ug_conveyor bearings   90 days
# 18          Inspect hoist annually  365 days
# 19        Lubricate hoist bearings   90 days
# 20           Inspect mill annually  365 days
# 21         Lubricate mill bearings   90 days
# 22           Inspect pump annually  365 days
# 23         Lubricate pump bearings   90 days
# 24            Inspect fan annually  365 days
# 25          Lubricate fan bearings   90 days
# 26    Inspect ug_conveyor annually  365 days
# 27  Lubricate ug_conveyor bearings   90 days
# 28    Inspect ug_conveyor annually  365 days
# 29  Lubricate ug_conveyor bearings   90 days
# 30          Inspect hoist annually  365 days
# 31        Lubricate hoist bearings   90 days
# 32          Inspect motor annually  365 days
# 33        Lubricate motor bearings   90 days
# 34           Inspect mill annually  365 days
# 35         Lubricate mill bearings   90 days
# 36          Inspect motor annually  365 days
# 37        Lubricate motor bearings   90 days
# 38          Inspect motor annually  365 days
# 39        Lubricate motor bearings   90 days
# 40           Inspect pump annually  365 days
# 41         Lubricate pump bearings   90 days
# 42           Inspect mill annually  365 days
# 43         Lubricate mill bearings   90 days
# 44           Inspect mill annually  365 days
# 45         Lubricate mill bearings   90 days
# 46    Inspect ug_conveyor annually  365 days
# 47  Lubricate ug_conveyor bearings   90 days
# 48           Inspect pump annually  365 days
# 49         Lubricate pump bearings   90 days
