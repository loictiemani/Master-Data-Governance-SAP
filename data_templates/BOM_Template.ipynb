# %%
import sys
sys.path.append("../scripts")

# %%
from Generate_template import generate_asset_data  # or paste the function in the notebook

_, bom_df, _, _, _ = generate_asset_data()
bom_df.head(50)
# Out:
#    Equipment ID Component ID    Component Description      Type  Quantity
# 0         EQ001   COMP-001-1        MOTOR Component 1      Wear         1
# 1         EQ001   COMP-001-2        MOTOR Component 2  Critical         2
# 2         EQ002   COMP-002-1         MILL Component 1  Critical         5
# 3         EQ002   COMP-002-2         MILL Component 2      Wear         2
# 4         EQ002   COMP-002-3         MILL Component 3      Wear         4
# 5         EQ002   COMP-002-4         MILL Component 4     Spare         1
# 6         EQ003   COMP-003-1        MOTOR Component 1      Wear         1
# 7         EQ003   COMP-003-2        MOTOR Component 2  Critical         1
# 8         EQ003   COMP-003-3        MOTOR Component 3     Spare         4
# 9         EQ004   COMP-004-1         PUMP Component 1     Spare         5
# 10        EQ004   COMP-004-2         PUMP Component 2      Wear         2
# 11        EQ005   COMP-005-1  UG_CONVEYOR Component 1     Spare         4
# 12        EQ005   COMP-005-2  UG_CONVEYOR Component 2  Critical         1
# 13        EQ006   COMP-006-1  UG_CONVEYOR Component 1     Spare         4
# 14        EQ006   COMP-006-2  UG_CONVEYOR Component 2      Wear         4
# 15        EQ007   COMP-007-1          FAN Component 1     Spare         4
# 16        EQ007   COMP-007-2          FAN Component 2      Wear         4
# 17        EQ007   COMP-007-3          FAN Component 3      Wear         4
# 18        EQ008   COMP-008-1        MOTOR Component 1     Spare         3
# 19        EQ008   COMP-008-2        MOTOR Component 2     Spare         1
# 20        EQ009   COMP-009-1  UG_CONVEYOR Component 1     Spare         5
# 21        EQ009   COMP-009-2  UG_CONVEYOR Component 2      Wear         5
# 22        EQ010   COMP-010-1        HOIST Component 1     Spare         5
# 23        EQ010   COMP-010-2        HOIST Component 2     Spare         2
# 24        EQ011   COMP-011-1         MILL Component 1  Critical         1
# 25        EQ011   COMP-011-2         MILL Component 2  Critical         1
# 26        EQ011   COMP-011-3         MILL Component 3      Wear         5
# 27        EQ011   COMP-011-4         MILL Component 4  Critical         5
# 28        EQ012   COMP-012-1         PUMP Component 1      Wear         4
# 29        EQ012   COMP-012-2         PUMP Component 2     Spare         3
# 30        EQ013   COMP-013-1          FAN Component 1  Critical         5
# 31        EQ013   COMP-013-2          FAN Component 2     Spare         1
# 32        EQ013   COMP-013-3          FAN Component 3  Critical         2
# 33        EQ014   COMP-014-1  UG_CONVEYOR Component 1     Spare         3
# 34        EQ014   COMP-014-2  UG_CONVEYOR Component 2      Wear         2
# 35        EQ015   COMP-015-1  UG_CONVEYOR Component 1  Critical         5
# 36        EQ015   COMP-015-2  UG_CONVEYOR Component 2     Spare         5
# 37        EQ015   COMP-015-3  UG_CONVEYOR Component 3      Wear         1
# 38        EQ015   COMP-015-4  UG_CONVEYOR Component 4     Spare         3
# 39        EQ016   COMP-016-1        HOIST Component 1      Wear         5
# 40        EQ016   COMP-016-2        HOIST Component 2     Spare         3
# 41        EQ016   COMP-016-3        HOIST Component 3     Spare         3
# 42        EQ017   COMP-017-1        MOTOR Component 1  Critical         4
# 43        EQ017   COMP-017-2        MOTOR Component 2      Wear         1
# 44        EQ018   COMP-018-1         MILL Component 1  Critical         4
# 45        EQ018   COMP-018-2         MILL Component 2  Critical         4
# 46        EQ019   COMP-019-1        MOTOR Component 1     Spare         5
# 47        EQ019   COMP-019-2        MOTOR Component 2     Spare         3
# 48        EQ019   COMP-019-3        MOTOR Component 3  Critical         5
# 49        EQ019   COMP-019-4        MOTOR Component 4     Spare         4
