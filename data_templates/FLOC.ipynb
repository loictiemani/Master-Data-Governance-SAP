# %%
import sys
sys.path.append("../scripts")

# %%
from Generate_template import generate_asset_data  # or paste the function in the notebook

equipment_df, bom_df, floc_df, task_list_df, fmeca_df, failure_history_df, runtime_log_df = generate_asset_data()
floc_df.head(50)
# Out:
#         Functional Location                Area    Subarea        Class
# 0         PLANT01-MOTOR-001        MOTOR Area 2  Subarea 4        MOTOR
# 1          PLANT01-MILL-002         MILL Area 2  Subarea 4         MILL
# 2         PLANT01-MOTOR-003        MOTOR Area 2  Subarea 2        MOTOR
# 3          PLANT01-PUMP-004         PUMP Area 1  Subarea 2         PUMP
# 4   PLANT01-UG_CONVEYOR-005  UG_CONVEYOR Area 2  Subarea 3  UG_CONVEYOR
# 5   PLANT01-UG_CONVEYOR-006  UG_CONVEYOR Area 1  Subarea 1  UG_CONVEYOR
# 6           PLANT01-FAN-007          FAN Area 1  Subarea 5          FAN
# 7         PLANT01-MOTOR-008        MOTOR Area 2  Subarea 3        MOTOR
# 8   PLANT01-UG_CONVEYOR-009  UG_CONVEYOR Area 2  Subarea 5  UG_CONVEYOR
# 9         PLANT01-HOIST-010        HOIST Area 2  Subarea 5        HOIST
# 10         PLANT01-MILL-011         MILL Area 1  Subarea 3         MILL
# 11         PLANT01-PUMP-012         PUMP Area 3  Subarea 2         PUMP
# 12          PLANT01-FAN-013          FAN Area 2  Subarea 5          FAN
# 13  PLANT01-UG_CONVEYOR-014  UG_CONVEYOR Area 2  Subarea 2  UG_CONVEYOR
# 14  PLANT01-UG_CONVEYOR-015  UG_CONVEYOR Area 2  Subarea 3  UG_CONVEYOR
# 15        PLANT01-HOIST-016        HOIST Area 1  Subarea 1        HOIST
# 16        PLANT01-MOTOR-017        MOTOR Area 1  Subarea 5        MOTOR
# 17         PLANT01-MILL-018         MILL Area 2  Subarea 4         MILL
# 18        PLANT01-MOTOR-019        MOTOR Area 2  Subarea 3        MOTOR
# 19        PLANT01-MOTOR-020        MOTOR Area 3  Subarea 5        MOTOR
# 20         PLANT01-PUMP-021         PUMP Area 3  Subarea 1         PUMP
# 21         PLANT01-MILL-022         MILL Area 1  Subarea 2         MILL
# 22         PLANT01-MILL-023         MILL Area 3  Subarea 5         MILL
# 23  PLANT01-UG_CONVEYOR-024  UG_CONVEYOR Area 3  Subarea 2  UG_CONVEYOR
# 24         PLANT01-PUMP-025         PUMP Area 2  Subarea 2         PUMP
# 25         PLANT01-MILL-026         MILL Area 3  Subarea 4         MILL
# 26          PLANT01-FAN-027          FAN Area 2  Subarea 1          FAN
# 27         PLANT01-PUMP-028         PUMP Area 1  Subarea 4         PUMP
# 28          PLANT01-FAN-029          FAN Area 1  Subarea 4          FAN
# 29        PLANT01-HOIST-030        HOIST Area 1  Subarea 4        HOIST
# 30         PLANT01-PUMP-031         PUMP Area 3  Subarea 4         PUMP
# 31          PLANT01-FAN-032          FAN Area 1  Subarea 5          FAN
# 32        PLANT01-HOIST-033        HOIST Area 3  Subarea 5        HOIST
# 33         PLANT01-MILL-034         MILL Area 3  Subarea 5         MILL
# 34  PLANT01-UG_CONVEYOR-035  UG_CONVEYOR Area 3  Subarea 3  UG_CONVEYOR
# 35        PLANT01-MOTOR-036        MOTOR Area 2  Subarea 1        MOTOR
# 36        PLANT01-HOIST-037        HOIST Area 2  Subarea 4        HOIST
# 37         PLANT01-MILL-038         MILL Area 3  Subarea 5         MILL
# 38         PLANT01-MILL-039         MILL Area 1  Subarea 3         MILL
# 39         PLANT01-MILL-040         MILL Area 2  Subarea 3         MILL
# 40  PLANT01-UG_CONVEYOR-041  UG_CONVEYOR Area 3  Subarea 3  UG_CONVEYOR
# 41         PLANT01-PUMP-042         PUMP Area 3  Subarea 1         PUMP
# 42        PLANT01-MOTOR-043        MOTOR Area 1  Subarea 1        MOTOR
# 43          PLANT01-FAN-044          FAN Area 2  Subarea 5          FAN
# 44        PLANT01-MOTOR-045        MOTOR Area 3  Subarea 5        MOTOR
# 45        PLANT01-MOTOR-046        MOTOR Area 1  Subarea 4        MOTOR
# 46         PLANT01-PUMP-047         PUMP Area 2  Subarea 2         PUMP
# 47        PLANT01-HOIST-048        HOIST Area 2  Subarea 4        HOIST
# 48          PLANT01-FAN-049          FAN Area 2  Subarea 4          FAN
# 49        PLANT01-HOIST-050        HOIST Area 2  Subarea 4        HOIST
