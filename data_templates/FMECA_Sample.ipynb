# %%
import sys
sys.path.append("../scripts")

# %%
from Generate_template import generate_asset_data  # or paste the function in the notebook

_, _, _, _, fmeca_df = generate_asset_data()
fmeca_df.head(50)
# Out:
#    Equipment ID Failure Mode ID              Failure Mode  Severity  \
# 0         EQ001        FAIL-001        MOTOR Failure Mode    Medium
# 1         EQ002        FAIL-002         MILL Failure Mode      High
# 2         EQ003        FAIL-003        MOTOR Failure Mode    Medium
# 3         EQ004        FAIL-004         PUMP Failure Mode      High
# 4         EQ005        FAIL-005  UG_CONVEYOR Failure Mode    Medium
# 5         EQ006        FAIL-006  UG_CONVEYOR Failure Mode    Medium
# 6         EQ007        FAIL-007          FAN Failure Mode  Critical
# 7         EQ008        FAIL-008        MOTOR Failure Mode    Medium
# 8         EQ009        FAIL-009  UG_CONVEYOR Failure Mode    Medium
# 9         EQ010        FAIL-010        HOIST Failure Mode  Critical
# 10        EQ011        FAIL-011         MILL Failure Mode    Medium
# 11        EQ012        FAIL-012         PUMP Failure Mode    Medium
# 12        EQ013        FAIL-013          FAN Failure Mode    Medium
# 13        EQ014        FAIL-014  UG_CONVEYOR Failure Mode  Critical
# 14        EQ015        FAIL-015  UG_CONVEYOR Failure Mode  Critical
# 15        EQ016        FAIL-016        HOIST Failure Mode      High
# 16        EQ017        FAIL-017        MOTOR Failure Mode    Medium
# 17        EQ018        FAIL-018         MILL Failure Mode    Medium
# 18        EQ019        FAIL-019        MOTOR Failure Mode      High
# 19        EQ020        FAIL-020        MOTOR Failure Mode      High
# 20        EQ021        FAIL-021         PUMP Failure Mode      High
# 21        EQ022        FAIL-022         MILL Failure Mode      High
# 22        EQ023        FAIL-023         MILL Failure Mode      High
# 23        EQ024        FAIL-024  UG_CONVEYOR Failure Mode    Medium
# 24        EQ025        FAIL-025         PUMP Failure Mode      High
# 25        EQ026        FAIL-026         MILL Failure Mode  Critical
# 26        EQ027        FAIL-027          FAN Failure Mode  Critical
# 27        EQ028        FAIL-028         PUMP Failure Mode  Critical
# 28        EQ029        FAIL-029          FAN Failure Mode    Medium
# 29        EQ030        FAIL-030        HOIST Failure Mode  Critical
# 30        EQ031        FAIL-031         PUMP Failure Mode    Medium
# 31        EQ032        FAIL-032          FAN Failure Mode  Critical
# 32        EQ033        FAIL-033        HOIST Failure Mode    Medium
# 33        EQ034        FAIL-034         MILL Failure Mode  Critical
# 34        EQ035        FAIL-035  UG_CONVEYOR Failure Mode      High
# 35        EQ036        FAIL-036        MOTOR Failure Mode      High
# 36        EQ037        FAIL-037        HOIST Failure Mode  Critical
# 37        EQ038        FAIL-038         MILL Failure Mode    Medium
# 38        EQ039        FAIL-039         MILL Failure Mode  Critical
# 39        EQ040        FAIL-040         MILL Failure Mode  Critical
# 40        EQ041        FAIL-041  UG_CONVEYOR Failure Mode  Critical
# 41        EQ042        FAIL-042         PUMP Failure Mode    Medium
# 42        EQ043        FAIL-043        MOTOR Failure Mode    Medium
# 43        EQ044        FAIL-044          FAN Failure Mode  Critical
# 44        EQ045        FAIL-045        MOTOR Failure Mode  Critical
# 45        EQ046        FAIL-046        MOTOR Failure Mode      High
# 46        EQ047        FAIL-047         PUMP Failure Mode    Medium
# 47        EQ048        FAIL-048        HOIST Failure Mode  Critical
# 48        EQ049        FAIL-049          FAN Failure Mode    Medium
# 49        EQ050        FAIL-050        HOIST Failure Mode  Critical
#
#       Recommended Action Criticality
# 0    Planned Replacement         Low
# 1   Condition Monitoring        High
# 2    Planned Replacement         Low
# 3   Condition Monitoring        High
# 4    Planned Replacement         Low
# 5    Planned Replacement      Medium
# 6   Condition Monitoring        High
# 7   Condition Monitoring      Medium
# 8    Planned Replacement        High
# 9    Planned Replacement      Medium
# 10  Condition Monitoring         Low
# 11   Planned Replacement        High
# 12  Condition Monitoring         Low
# 13  Condition Monitoring         Low
# 14   Planned Replacement        High
# 15   Planned Replacement      Medium
# 16  Condition Monitoring      Medium
# 17   Planned Replacement         Low
# 18  Condition Monitoring         Low
# 19  Condition Monitoring      Medium
# 20   Planned Replacement         Low
# 21  Condition Monitoring        High
# 22   Planned Replacement        High
# 23  Condition Monitoring         Low
# 24   Planned Replacement        High
# 25   Planned Replacement         Low
# 26  Condition Monitoring         Low
# 27  Condition Monitoring        High
# 28  Condition Monitoring        High
# 29   Planned Replacement         Low
# 30   Planned Replacement      Medium
# 31   Planned Replacement         Low
# 32   Planned Replacement         Low
# 33  Condition Monitoring      Medium
# 34  Condition Monitoring         Low
# 35  Condition Monitoring         Low
# 36   Planned Replacement        High
# 37  Condition Monitoring         Low
# 38   Planned Replacement        High
# 39   Planned Replacement        High
# 40   Planned Replacement         Low
# 41  Condition Monitoring        High
# 42  Condition Monitoring      Medium
# 43   Planned Replacement         Low
# 44   Planned Replacement      Medium
# 45  Condition Monitoring         Low
# 46  Condition Monitoring        High
# 47   Planned Replacement         Low
# 48  Condition Monitoring        High
# 49  Condition Monitoring        High
